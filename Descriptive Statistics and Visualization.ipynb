# %% [markdown]
# ### Descriptive Statistics and Charts
# ### Prepared by: Dhrub Satyam
# ### Contact: dsatyam1@gmail.com

# %% [markdown]
# ## Mean, Median, Mode, Standard Deviation and Variance

# %%
#Mean, Median, Mode, Standard Deviation, Variance
import numpy as np
from scipy import stats
data = [1,1,2,2,3,4]

x = np.mean(data)
y = np.median(data)
z = stats.mode(data)   # Returns the first number when we have no mode or multiple modes.
m = np.std(data)
n = np.var(data)

print(x)
print(y)
print(z)
print(m)
print(n)
# Out:
# 2.1666666666666665
# 2.0
# ModeResult(mode=array([1]), count=array([2]))
# 1.0671873729054748
# 1.1388888888888888

# %% [markdown]
# ## 5 Number Summary

# %% [markdown]
# ##### Method - 1

# %%
data = [0, 0, 1, 2, 63, 61, 27, 13]
print(np.percentile(data, [0, 25, 50, 75, 100], interpolation = 'midpoint'))

# %% [markdown]
# ##### Method - 2

# %%
import numpy as np

def fivept(data):
    """To find out the Five number summary"""
    
    return np.percentile(data, [0, 25, 50, 75, 100], interpolation = 'midpoint')

datapoints = [0, 0, 1, 2, 63, 61, 27, 13]

print(fivept(datapoints))
# Out:
# [ 0.   0.5  7.5 44.  63. ]

# %%
#Line Chart
import matplotlib.pyplot as plt
plt.plot([1, 2, 3, 4], [1, 4, 9, 16])
plt.ylabel('Y-Axis')
plt.xlabel('X-Axis')
plt.show()

# %%
#Bar Chart
import matplotlib.pyplot as plt
plt.bar(['Python', 'Stats', 'ML', 'Deep Learning', 'SQL'],[80,69,74,56,12], label="DS Student Count", color = 'b')
#plt.legend()
plt.xlabel('Subject', color = 'r')
plt.ylabel('No. of Students', color = 'r')
plt.title('Sub wise no. of Student in DS')
plt.show()

# %%
#Histogram
import matplotlib.pyplot as plt

x = [10, 11,18, 15, 28,25,30,38,39,40,45,48,49,50,42,32,24,54,65,12]
plt.hist(x, bins = 5)
plt.show()

# %%
#Pie Chart
import matplotlib.pyplot as plt

# Data to plot
labels = 'R', 'Java', 'Python', 'SAS'
sizes = [215, 130, 245, 210]
colors = ['red', 'green', 'blue', 'orange']
#explode = (0, 0, 0.1, 0)  # explode 3rd slice

# Plot
#plt.pie(sizes, explode=explode, labels=labels, colors=colors, autopct='%1.1f%%')
plt.pie(sizes, labels=labels, colors=colors,autopct='%1.1f%%')

#plt.axis('equal')
plt.show()

# %%
#Donut Chart
labels = 'Frogs', 'Hogs', 'Dogs', 'Logs'
sizes = [15, 30, 45, 10]
colors = ['yellowgreen', 'gold', 'lightskyblue', 'lightcoral']
explode = (0, 0, 0, 0)  # explode a slice if required

plt.pie(sizes, explode=explode, labels=labels, colors=colors,
        autopct='%1.1f%%', shadow=True)
        
#draw a circle at the center of pie to make it look like a donut
centre_circle = plt.Circle((0,0),0.75,color='black', fc='white',linewidth=1.25)
fig = plt.gcf()
fig.gca().add_artist(centre_circle)


# Set aspect ratio to be equal so that pie is drawn as a circle.
plt.axis('equal')
plt.show()

# %%
#Scatter Plot
import matplotlib.pyplot as plt
x = [1,2,3,4,5,6,7,8]
y = [5,2,4,2,1,4,5,2]
m = [4,5,7,8,9,4,6,8]

plt.scatter(x,y, label='My Label', color='g', s=25, marker="o")
plt.scatter(m,y, label='My Label2', color='r', s=25, marker="x")
plt.xlabel('x')
plt.ylabel('y')
plt.title('Scatter Plot')
plt.legend()
plt.show()

# %%
# Finding Pearson Correlation between variables
import numpy as np
import scipy.stats
x = np.arange(10, 20)
y = np.array([2, 1, 4, 5, 8, 12, 18, 25, 96, 48])
scipy.stats.pearsonr(x, y)    # Pearson's r
# Out:
# (0.7586402890911869, 0.010964341301680832)

# %%
#Skewness & Kurtosis
import numpy as np
from scipy.stats import kurtosis, skew
x = np.random.normal(0, 2, 10000)   # create random values based on a normal distribution

print(kurtosis(x))
print(skew(x))

#print('excess kurtosis of normal distribution (should be 0): {}'.format( kurtosis(x) ))
#print('skewness of normal distribution (should be 0): {}'.format( skew(x) ))
# Out:
# 0.015637500727866183
# 0.011308261446511522

# %%
#Box Plot
import pandas as pd
import numpy as np
df = pd.DataFrame(np.random.rand(10, 5), columns=['A', 'B', 'C', 'D', 'E'])
df.plot.box()
